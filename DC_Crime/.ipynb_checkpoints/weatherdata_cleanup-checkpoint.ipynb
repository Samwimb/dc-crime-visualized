# %%
import pandas as pd
import numpy as py
import datetime as dt

# %%
# defining the file path
filepath = "data/2018weatherdata_csv.csv"
filepath
# Out:
# 'data/2018weatherdata_csv.csv'

# %%
# Open the file
weather_df = pd.read_csv(filepath)

# %%
weather_df.head()
# Out:
#      USAF   WBAN  YR--MODAHRMN        DATE  DIR SPD  GUS  CLG  SKC  L ...  \
# 0  724030  93738  2.018010e+11  2018-01-01  ***   0  ***  722  SCT  * ...
# 1  724030  93738  2.018010e+11  2018-01-01  320   5  ***  722  SCT  * ...
# 2  724030  93738  2.018010e+11  2018-01-01  ***   0  ***  722  CLR  * ...
# 3  724030  93738  2.018010e+11  2018-01-01  990   3  ***  722  CLR  * ...
# 4  724030  93738  2.018010e+11  2018-01-01  320   6  ***  722  CLR  * ...
#
#       SLP    ALT     STP  MAX  MIN  PCP01  PCP06  PCP24  PCPXX  SD
# 0  1029.5  *****  1017.8   21   13  *****   0.00  *****  *****  **
# 1  1030.1  30.41  1017.9  ***  ***   0.00  *****  *****  *****  **
# 2  1030.6  30.42  1018.3  ***  ***   0.00  *****  *****  *****  **
# 3  1030.5  30.42  1018.3  ***  ***   0.00  *****  *****  *****  **
# 4  1031.0  30.43  1018.6  ***  ***   0.00  *****  *****  *****  **
#
# [5 rows x 34 columns]

# %%
# Drop the rows with no temp
weather_df.dropna(subset=['TEMP'])
weather_df.head()
# Out:
#      USAF   WBAN  YR--MODAHRMN        DATE  DIR SPD  GUS  CLG  SKC  M ...  \
# 0  724030  93738  2.018010e+11  2018-01-01  ***   0  ***  722  SCT  * ...
# 1  724030  93738  2.018010e+11  2018-01-01  320   5  ***  722  SCT  * ...
# 2  724030  93738  2.018010e+11  2018-01-01  ***   0  ***  722  CLR  * ...
# 3  724030  93738  2.018010e+11  2018-01-01  990   3  ***  722  CLR  * ...
# 4  724030  93738  2.018010e+11  2018-01-01  320   6  ***  722  CLR  * ...
#
#       SLP    ALT     STP  MAX  MIN  PCP01  PCP06  PCP24  PCPXX  SD
# 0  1029.5  *****  1017.8   21   13  *****   0.00  *****  *****  **
# 1  1030.1  30.41  1017.9  ***  ***   0.00  *****  *****  *****  **
# 2  1030.6  30.42  1018.3  ***  ***   0.00  *****  *****  *****  **
# 3  1030.5  30.42  1018.3  ***  ***   0.00  *****  *****  *****  **
# 4  1031.0  30.43  1018.6  ***  ***   0.00  *****  *****  *****  **
#
# [5 rows x 33 columns]

# %%
# Drop columns with no data
del weather_df['M']
del weather_df['H']
del weather_df['MW']
del weather_df['MW_1']
del weather_df['MW_2']
del weather_df['MW_3']
del weather_df['AW']
del weather_df['AW_4']
del weather_df['AW_5']
del weather_df['AW_6']
del weather_df['W']
del weather_df['PCP01']
del weather_df['PCP06']
del weather_df['PCP24']
del weather_df['PCPXX']
del weather_df['SD']

# %%
weather_df.head()
# Out:
#      USAF   WBAN  YR--MODAHRMN        DATE  DIR SPD  GUS  CLG  SKC   VSB TEMP  \
# 0  724030  93738  2.018010e+11  2018-01-01  ***   0  ***  722  SCT  10.0   14
# 1  724030  93738  2.018010e+11  2018-01-01  320   5  ***  722  SCT  10.0   15
# 2  724030  93738  2.018010e+11  2018-01-01  ***   0  ***  722  CLR  10.0   11
# 3  724030  93738  2.018010e+11  2018-01-01  990   3  ***  722  CLR  10.0   11
# 4  724030  93738  2.018010e+11  2018-01-01  320   6  ***  722  CLR  10.0   13
#
#   DEWP     SLP    ALT     STP  MAX  MIN
# 0    6  1029.5  *****  1017.8   21   13
# 1    8  1030.1  30.41  1017.9  ***  ***
# 2    6  1030.6  30.42  1018.3  ***  ***
# 3    4  1030.5  30.42  1018.3  ***  ***
# 4    3  1031.0  30.43  1018.6  ***  ***

# %%
#weather_df.count()
# Out:
# USAF            12729
# WBAN            12729
# YR--MODAHRMN    12729
# DATE            12729
# DIR             12729
# SPD             12729
# GUS             12729
# CLG             12729
# SKC             12729
# VSB             12729
# TEMP            12729
# DEWP            12729
# SLP             12729
# ALT             12729
# STP             12729
# MAX             12729
# MIN             12729
# dtype: int64
